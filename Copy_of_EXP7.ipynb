# %% [markdown]
# <a href="https://colab.research.google.com/github/pankajkumaryadav-ai-ds/AI-DS-LAB/blob/main/Copy_of_EXP7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {'school':['s001','s002','s003','s001','s002','s004'],
        'class':['v','v','vi','vi','v','vi'],
        "name":['AlbertoFranco','Gino Mcneill','Ryan Parkes','Eesha Hinton','Gino Mcneill','David Parkes'],
        'date_Of_Birth':['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
        'age':[12,12,13,13,14,12],
        'height':[173,192,186,167,151,159],
        'weight':[35,32,33,30,31,32],
        'Address':['street1','street2','street3','street1','street2','street4']
        }

# %%
df = pd.DataFrame(data, index = ['S1','S2','S3','S4','S5','S6'])
df
# Out:
#    school class           name date_Of_Birth  age  height  weight  Address
# S1   s001     v  AlbertoFranco    15/05/2002   12     173      35  street1
# S2   s002     v   Gino Mcneill    17/05/2002   12     192      32  street2
# S3   s003    vi    Ryan Parkes    16/02/1999   13     186      33  street3
# S4   s001    vi   Eesha Hinton    25/09/1998   13     167      30  street1
# S5   s002     v   Gino Mcneill    11/05/2002   14     151      31  street2
# S6   s004    vi   David Parkes    15/09/1997   12     159      32  street4

# %%
m1 = np.random.randint(25,50,6)
m1
# Out:
# array([41, 49, 26, 46, 45, 47])

# %%
m2 = np.random.randint(30,50,6)
m2
# Out:
# array([47, 38, 48, 48, 49, 39])

# %%
m3 = np.random.randint(30,50,6)
m3
# Out:
# array([36, 47, 30, 34, 47, 39])

# %%
df['marks1'] = m1
df['marks2'] = m2
df['marks3'] = m3
df
# Out:
#    school class           name date_Of_Birth  age  height  weight  Address  \
# S1   s001     v  AlbertoFranco    15/05/2002   12     173      35  street1
# S2   s002     v   Gino Mcneill    17/05/2002   12     192      32  street2
# S3   s003    vi    Ryan Parkes    16/02/1999   13     186      33  street3
# S4   s001    vi   Eesha Hinton    25/09/1998   13     167      30  street1
# S5   s002     v   Gino Mcneill    11/05/2002   14     151      31  street2
# S6   s004    vi   David Parkes    15/09/1997   12     159      32  street4
#
#     marks1  marks2  marks3
# S1      41      47      36
# S2      49      38      47
# S3      26      48      30
# S4      46      48      34
# S5      45      49      47
# S6      47      39      39

# %%
df.plot.barh(x='name', y = ['marks1','marks2','marks3'])

# %%
df.plot.barh(stacked=True,x='name', y = ['marks1','marks2','marks3'])

# %%
t = ['boy','girl']
df['gender'] = np.random.randint(0,2,len(df['school']))
df = df.replace(0,t[0])
df = df.replace(1,t[1])
df
# Out:
#    school class           name date_Of_Birth  age  height  weight  Address  \
# S1   s001     v  AlbertoFranco    15/05/2002   12     173      35  street1
# S2   s002     v   Gino Mcneill    17/05/2002   12     192      32  street2
# S3   s003    vi    Ryan Parkes    16/02/1999   13     186      33  street3
# S4   s001    vi   Eesha Hinton    25/09/1998   13     167      30  street1
# S5   s002     v   Gino Mcneill    11/05/2002   14     151      31  street2
# S6   s004    vi   David Parkes    15/09/1997   12     159      32  street4
#
#     marks1  marks2  marks3 gender
# S1      41      47      36   girl
# S2      49      38      47    boy
# S3      26      48      30    boy
# S4      46      48      34    boy
# S5      45      49      47    boy
# S6      47      39      39   girl

# %%
df.describe()
# Out:
#              age      height     weight     marks1     marks2     marks3
# count   6.000000    6.000000   6.000000   6.000000   6.000000   6.000000
# mean   12.666667  171.333333  32.166667  42.333333  44.833333  38.833333
# std     0.816497   15.680136   1.722401   8.430105   4.956477   6.968979
# min    12.000000  151.000000  30.000000  26.000000  38.000000  30.000000
# 25%    12.000000  161.000000  31.250000  42.000000  41.000000  34.500000
# 50%    12.500000  170.000000  32.000000  45.500000  47.500000  37.500000
# 75%    13.000000  182.750000  32.750000  46.750000  48.000000  45.000000
# max    14.000000  192.000000  35.000000  49.000000  49.000000  47.000000

# %%
df[df[]].sum()
# Out:
# school                                    s001s002s003s001s002s004
# class                                                    vvvivivvi
# name             AlbertoFrancoGino McneillRyan ParkesEesha Hint...
# date_Of_Birth    15/05/200217/05/200216/02/199925/09/199811/05/...
# age                                                             76
# height                                                        1028
# weight                                                         193
# Address                 street1street2street3street1street2street4
# marks1                                                         254
# marks2                                                         269
# marks3                                                         233
# gender                                        girlboyboyboyboygirl
# dtype: object

# %%
print('BOYS DESCRIPTION')
df[df['gender'] == 'boy'].describe()
# Out:
# BOYS DESCRIPTION
#              age      height     weight     marks1     marks2     marks3
# count   4.000000    4.000000   4.000000   4.000000   4.000000   4.000000
# mean   13.000000  174.000000  31.500000  41.500000  45.750000  39.500000
# std     0.816497   18.672618   1.290994  10.472185   5.188127   8.812869
# min    12.000000  151.000000  30.000000  26.000000  38.000000  30.000000
# 25%    12.750000  163.000000  30.750000  40.250000  45.500000  33.000000
# 50%    13.000000  176.500000  31.500000  45.500000  48.000000  40.500000
# 75%    13.250000  187.500000  32.250000  46.750000  48.250000  47.000000
# max    14.000000  192.000000  33.000000  49.000000  49.000000  47.000000

# %%
print('GIRLS DESCRIPTION')
df[df['gender'] == 'girl'].describe()
# Out:
# GIRLS DESCRIPTION
#         age      height    weight     marks1     marks2    marks3
# count   2.0    2.000000   2.00000   2.000000   2.000000   2.00000
# mean   12.0  166.000000  33.50000  44.000000  43.000000  37.50000
# std     0.0    9.899495   2.12132   4.242641   5.656854   2.12132
# min    12.0  159.000000  32.00000  41.000000  39.000000  36.00000
# 25%    12.0  162.500000  32.75000  42.500000  41.000000  36.75000
# 50%    12.0  166.000000  33.50000  44.000000  43.000000  37.50000
# 75%    12.0  169.500000  34.25000  45.500000  45.000000  38.25000
# max    12.0  173.000000  35.00000  47.000000  47.000000  39.00000
