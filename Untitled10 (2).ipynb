# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("1.csv")
df
# Out:
#   product    size  color price
# 0   shirt   large    red  $250
# 1   pants  medium  black  $500
# 2   shirt  medium   blue  $300

# %%
x=pd.read_excel("/content/Salary.xlsx")
x
# Out:
#    Region   Age   Income OnlineShopper
# 0   India  49.0  86400.0            No
# 1  Brazil  32.0  57600.0           Yes
# 2     USA  35.0  64800.0            No
# 3  Brazil  43.0  73200.0            No
# 4     USA  45.0      NaN           Yes
# 5   India  40.0  69600.0           Yes
# 6  Brazil   NaN  62400.0            No
# 7   India  53.0  94800.0           Yes
# 8     USA  55.0  99600.0            No
# 9   India  42.0  80400.0           Yes

# %%
df=pd.read_csv("/content/b.txt",sep=' ',header=None,names=["boys","girls"])
x=pd.DataFrame(df)
x
# Out:
#    boys  girls
# 0  boys  marks
# 1   abc    100
# 2   def     99
# 3   ghi     97

# %%
df=pd.read_table("/content/b.txt",delimiter=" ")
df
# Out:
#   boys  marks
# 0  abc    100
# 1  def     99
# 2  ghi     97

# %%
dataset={'school':['s001','s002','s003','s001','s002','s004'], 
         'class':['V','V','V1','VI','V','V'], 
         'name':['aldertofranco','gino mcneli','ryanparkes','eesha hintion','gino','david parkes'], 
         'age':['12','13','134','15','16','17'], 
         'weigtht':['35','35','36','37','40','45'] }

# %%
x=pd.DataFrame(dataset,index=list("abcdef"))
x
# Out:
#   school class           name  age weigtht
# a   s001     V  aldertofranco   12      35
# b   s002     V    gino mcneli   13      35
# c   s003    V1     ryanparkes  134      36
# d   s001    VI  eesha hintion   15      37
# e   s002     V           gino   16      40
# f   s004     V   david parkes   17      45

# %%
marks1=[1001,1002,1003,1004,1005,1006]
marks2=[1009,1010,1012,1013,1014,1015]
marks3=[500,600,700,800,900,1000]
x["marks1"]=marks1
x["marks2"]=marks2
x["marks3"]=marks3
x
# Out:
#   school class           name  age weigtht  marks1  marks2  marks3
# a   s001     V  aldertofranco   12      35    1001    1009     500
# b   s002     V    gino mcneli   13      35    1002    1010     600
# c   s003    V1     ryanparkes  134      36    1003    1012     700
# d   s001    VI  eesha hintion   15      37    1004    1013     800
# e   s002     V           gino   16      40    1005    1014     900
# f   s004     V   david parkes   17      45    1006    1015    1000

# %%
a=x.plot.barh(figsize=(8, 10),zorder=2)
a

# %%
x.plot.barh(stacked=True, title='Car Specifications', color=("orange", "cyan"),figsize=(8, 10),zorder=2)
