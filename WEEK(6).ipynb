# %% [markdown]
# <a href="https://colab.research.google.com/github/pankajkumaryadav-ai-ds/AI-DS-LAB/blob/main/WEEK(6).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
data=pd.read_csv("/content/pankaj.csv")
data.head()
# Out:
#    RollNo      Name         Address
# 0   12101   Nivetha      “Mylapore”
# 1   12102   Lavanya         “Adyar”
# 2   12103       Ram   “Gopalapuram”
# 3   12104    Pankaj          ongole
# 4   12105     Tarun           Vizag

# %%
data={"school":["s001","s002","s003","s001","s002","s004"],
      "Class":["V","V","VI","VI","V","VI"],
      "name":["AlbertoFranco","Gino Mcneill","Ryan Parkes","Eesha Hinton","Gino Mcneill","David Pakes"],
      "date_Of_Birth":["15/05/2002","17/05/2002","16/02/1999","25/09/1998","11/05/2002","15/09/1997"],
      "age":[12,12,13,13,14,12],
      "height":[173,192,186,167,151,159],
      "weight":[35,32,33,30,31,32],
      "Adress":["street1","street2","street3","street1","street2","street4"]}
d1=pd.DataFrame(data,index=["S1","S2","S3","S4","S5","S6"])
d1
# Out:
#    school Class           name date_Of_Birth  age  height  weight   Adress
# S1   s001     V  AlbertoFranco    15/05/2002   12     173      35  street1
# S2   s002     V   Gino Mcneill    17/05/2002   12     192      32  street2
# S3   s003    VI    Ryan Parkes    16/02/1999   13     186      33  street3
# S4   s001    VI   Eesha Hinton    25/09/1998   13     167      30  street1
# S5   s002     V   Gino Mcneill    11/05/2002   14     151      31  street2
# S6   s004    VI    David Pakes    15/09/1997   12     159      32  street4

# %%
d2={"marks1":[10,20,30,40,50,60],
    "marks2":[20,54,68,78,68,75],
    "marks3":[55,55,88,88,74,54]}
d3=pd.DataFrame(d2,index=["S1","S2","S3","S4","S5","S6"])

# %%
d=pd.concat([d1,d3],axis=1)
d
# Out:
#    school Class           name date_Of_Birth  age  height  weight   Adress  \
# S1   s001     V  AlbertoFranco    15/05/2002   12     173      35  street1
# S2   s002     V   Gino Mcneill    17/05/2002   12     192      32  street2
# S3   s003    VI    Ryan Parkes    16/02/1999   13     186      33  street3
# S4   s001    VI   Eesha Hinton    25/09/1998   13     167      30  street1
# S5   s002     V   Gino Mcneill    11/05/2002   14     151      31  street2
# S6   s004    VI    David Pakes    15/09/1997   12     159      32  street4
#
#     marks1  marks2  marks3
# S1      10      20      55
# S2      20      54      55
# S3      30      68      88
# S4      40      78      88
# S5      50      68      74
# S6      60      75      54

# %%
d3.plot.barh(title="Marks")

# %%
import matplotlib.pyplot as plt

# %%
d3.plot.barh(stacked=True, title='MARKS')

# %%
# 8th question
d4={"gender":["boy","girl","boy","girl","girl","boy"]}
d5=pd.DataFrame(d4,index=["S1","S2","S3","S4","S5","S6"])
d5
# Out:
#    gender
# S1    boy
# S2   girl
# S3    boy
# S4   girl
# S5   girl
# S6    boy

# %%
d6=pd.concat([d,d5],axis=1)
d6
# Out:
#    school Class           name date_Of_Birth  age  height  weight   Adress  \
# S1   s001     V  AlbertoFranco    15/05/2002   12     173      35  street1
# S2   s002     V   Gino Mcneill    17/05/2002   12     192      32  street2
# S3   s003    VI    Ryan Parkes    16/02/1999   13     186      33  street3
# S4   s001    VI   Eesha Hinton    25/09/1998   13     167      30  street1
# S5   s002     V   Gino Mcneill    11/05/2002   14     151      31  street2
# S6   s004    VI    David Pakes    15/09/1997   12     159      32  street4
#
#     marks1  marks2  marks3 gender
# S1      10      20      55    boy
# S2      20      54      55   girl
# S3      30      68      88    boy
# S4      40      78      88   girl
# S5      50      68      74   girl
# S6      60      75      54    boy

# %%
d6.describe()
# Out:
#              age      height     weight     marks1     marks2     marks3
# count   6.000000    6.000000   6.000000   6.000000   6.000000   6.000000
# mean   12.666667  171.333333  32.166667  35.000000  60.500000  69.000000
# std     0.816497   15.680136   1.722401  18.708287  21.501163  16.516658
# min    12.000000  151.000000  30.000000  10.000000  20.000000  54.000000
# 25%    12.000000  161.000000  31.250000  22.500000  57.500000  55.000000
# 50%    12.500000  170.000000  32.000000  35.000000  68.000000  64.500000
# 75%    13.000000  182.750000  32.750000  47.500000  73.250000  84.500000
# max    14.000000  192.000000  35.000000  60.000000  78.000000  88.000000

# %%
d6.sum()
# Out:
# school                                    s001s002s003s001s002s004
# Class                                                    VVVIVIVVI
# name             AlbertoFrancoGino McneillRyan ParkesEesha Hint...
# date_Of_Birth    15/05/200217/05/200216/02/199925/09/199811/05/...
# age                                                             76
# height                                                        1028
# weight                                                         193
# Adress                  street1street2street3street1street2street4
# marks1                                                         210
# marks2                                                         363
# marks3                                                         414
# gender                                       boygirlboygirlgirlboy
# dtype: object
